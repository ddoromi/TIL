# %% [markdown]
# ### 1. 클릭하면 https://www.ssafy.com/로 이동하는 버튼을 만드시오.

# %% [markdown]
# <a href="https://www.ssafy.com/">버튼</a>

# %% [markdown]
# ### 2. 다음 태그에서 잘못된 부분을 찾으시오.
# ![image.png](attachment:image.png)

# %%
img => a

# %% [markdown]
# ### 3. 당신은 현재 Resume.html 에서 작업 중이다. “내사진” 이라는 링크를누르면 Image 폴더 안에 my_photo를 띄워주는 a 태그 경로를 넣으시오.
# ![image.png](attachment:image.png)

# %% [markdown]
# <a href="../Image/my_photo.png">내 사진</a>
